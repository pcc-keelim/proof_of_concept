# %%
from data_warehouse import DataWarehouse

# %%
DataWarehouse.execute_query("SHOW TABLES")
# Out:
#                                     name
# 0             ce_comprehensive_encounter
# 1   ce_comprehensive_encounter_visit_map
# 2                     ce_patient_address
# 3                 ce_patient_description
# 4                   ce_patient_diagnosis
# 5                  ce_patient_disability
# 6                       ce_patient_email
# 7                   ce_patient_ethnicity
# 8          ce_patient_housing_insecurity
# 9                       ce_patient_ident
# 10                  ce_patient_insurance
# 11                   ce_patient_language
# 12             ce_patient_marital_status
# 13                       ce_patient_name
# 14                      ce_patient_phone
# 15                       ce_patient_race
# 16                      ce_patient_visit
# 17              ce_patient_visit_details
# 18            ce_patient_visit_insurance
# 19    ce_patient_visit_pds_care_provider
# 20                          contribution
# 21                           data_source
# ...

# %%
DataWarehouse.execute_query("DESCRIBE facility")
# Out:
#              column_name column_type null  key default  extra
# 0                   f.id     VARCHAR  YES  NaN     NaN    NaN
# 1                 f.name     VARCHAR  YES  NaN     NaN    NaN
# 2              f.address     VARCHAR  YES  NaN     NaN    NaN
# 3             f.address2     VARCHAR  YES  NaN     NaN    NaN
# 4                f.phone     VARCHAR  YES  NaN     NaN    NaN
# 5         f.contact_name     VARCHAR  YES  NaN     NaN    NaN
# 6        f.participating     VARCHAR  YES  NaN     NaN    NaN
# 7            f.join_date   TIMESTAMP  YES  NaN     NaN    NaN
# 8                f.email     VARCHAR  YES  NaN     NaN    NaN
# 9                 f.city     VARCHAR  YES  NaN     NaN    NaN
# 10               f.state     VARCHAR  YES  NaN     NaN    NaN
# 11                 f.zip     VARCHAR  YES  NaN     NaN    NaN
# 12             f.country     VARCHAR  YES  NaN     NaN    NaN
# 13  f.parent_facility_id     VARCHAR  YES  NaN     NaN    NaN
# ...

# %%
DataWarehouse.execute_query("select * from facility limit 1;")
# Out:
#                                    f.id  \
# 0  00005933-767f-468f-b81d-17dbdcbbb554
#
#                                               f.name        f.address  \
# 0  SSC GLEN BURNIE NORTH ARUNDEL OPERATING COMPAN...  313 HOSPITAL DR
#
#   f.address2       f.phone f.contact_name f.participating f.join_date f.email  \
# 0        NaN  832-467-5728                              0  2019-01-22
#
#         f.city  ... f.country f.parent_facility_id f.type f.latitude  \
# 0  GLEN BURNIE  ...       NaN                  NaN    snf
#
#   f.longitude f.url                          f.created_by        f.created_on  \
# 0                    e65d92d8-a2d8-4ae7-bd94-658be85a6011 2019-01-22 11:29:38
#
#         f.last_update f.county
# 0 2021-12-09 09:21:09
#
# [1 rows x 22 columns]
